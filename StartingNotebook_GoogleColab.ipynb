# %% [markdown]
# # JupyterLab basics

# %% [markdown]
# You are currently looking at a Jupyter notebook, displayed by a *JupyterLab* website (Google Colab in this case). A Jupyter notebook is a document that - among many other things - allows you to combine Python code, executed code output, and Markdown (formatted text) into a single file. We are going to be using these features to help us explore key spaces, hashing algorithms, and Rainbow Tables.
#
# You're free to edit the code in any Jupyter notebook, but be sure you know how to get a copy of the original in case you need to back out any changes you make.
#
# Let's cover some JupyterLab basics.

# %% [markdown]
# ## 1. Cells are used to hold all of the content of a Jupyter notebook

# %% [markdown]
# * Click the above heading once and you should see the outline of a cell.
# * Double-click the above heading, and you should see the text turn into unrendered Markdown text.
# * Hold down `Shift` then hit `Enter` on your keyboard. The cell's Markdown content should be rendered and then the next cell (the one this text is written in) will get highlighted.
#
# **As you just witnessed, cells have two "modes" -**
# 1. *Edit mode*, where you see and edit the un-rendered source of a cell. If you see a blinking cursor inside a selected cell, you're in *edit mode*. How you enter *edit mode* will depend on the state of a cell.
#     1. For a code or unrendered Markdown cell, a single click will do it.
#     2. For a rendered Markdown cell, a double click will revert to un-rendered Markdown, but leave you in *command mode*. However, a single click followed by `Enter` will take you right to *edit mode*.
# 2. *Command mode*, where you can add, move, or remove cells, and much more. If you've selected a cell but aren't seeing a blinking cursor, you're in *command mode*. To enter *command mode*...
#     1. For a code or unrendered Markdown cell, single click, then hit `Escape`
#     2. For rendered Markdown, just click once
#     3. In all cases, you can just click the white space beside your target cell.

# %% [markdown]
# **There are different types of cells, depending on the content they're meant to hold. The two we'll be using -**
# 1. *Code cell* - This is a cell that is used for entering and executing Python code. When a code cell is unselected, you can identify it by the pair of square brackets on the left side.
#     1. <img src="data:image/png;base64,..." />
#     2. You can convert a Markdown cell into a code cell by entering *command mode* and pressing `Ctrl+m` then `y`
# 2. *Markdown cell* - This cell is for entering and rendering Markdown text. These cells won't have the pair of square brackets when unselected. When selected, there will be text editing icons shown.
#     1. <img src="data:image/png;base64,..." />
#     2. You can convert a code cell into a Markdown cell by entering *command mode* and pressing `Ctrl+m` then `m`

# %% [markdown]
# **Adding and deleting cells -**
# In *command mode* you can add or delete cells by doing the following:
# 1. *Add a cell* -
#     1. Type `a` to add a new cell above the currently selected cell.
#     2. Type `b` to add a new cell below the currently selected cell.
#     3. You can also hover your mouse over the center-top or center-bottom of the cell to reveal an "Add code cell" button.
# 2. *Delete a cell* -
#     1. Select the cell you wish to delete and press `Ctrl+m`, then `d`.
#     2. In *edit mode* you can also use the little trash can icon on the top-right of the cell.

# %% [markdown]
# *Give it a try yourself* -
# 1. Click the whitespace to the right of the text in this cell to both select the cell, but also to ensure you're in *command mode*.
# 2. Type `b` to add a new blank cell below this one. The new cell will by default be a code cell in edit mode.
# 3. Type some Python code into this cell.
#     1. You could try `print('Hello world!')`
# 4. Hold down `Shift` and hit `Enter` to execute the cell.
#   1. This may take a couple of seconds since the first time you execute code Google Colab will need to start up some behind-the-scenes stuff for you. It should be faster after that.
# 5. The cell below the one you just executed will now be highlighted. Use the `up` arrow on your keyboard to highlight your code cell again.
# 6. Delete this cell by pressing `Ctrl+m` then `d`.
# 7. 👍

# %% [markdown]
# **And more! -**
# Check  out the options under the various menus above. Also check out the command palette under the "Tools" menu (there's a keyboard shortcut, but it doesn't work for me).

# %% [markdown]
# ## 2. Navigating the sections of these notebooks

# %% [markdown]
# In order to make navigating these notebooks easier the contents are broken up into sections using Markdown headers. You can see and navigate between the sections by click the "Table of Contents" button on the left-hand side of your browser:

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## 3. Hide sections

# %% [markdown]
# Things can get a little cluttered in notebooks as you deal with code, Markdown, and code output. To try to reduce this you can collapse sections in a Jupyter notebook.
#
# **By header -**
# Move your mouse to the left of a heading to reveal the "down arrow thingy," and click that.
# <img src="data:image/png;base64,..." />

# %% [markdown]
# Google Colab differs from JupyterLab in this area. Check out your options under the "View" menu, above.

# %% [markdown]
# ## 4. What I mean when I say "widgets"

# %% [markdown]
# *Jupyter Widgets* are a feature of Jupyter that allow for limited interactivity. They allow us to manipulate aspects of our Python code using familiar web page features like text boxes. As an example, the code in the following cell creates a simple widget. Click the cell and then hit `Shift+Enter` to execute.

# %%
#@title
# `ipywidgets` is the Jupyter widgets Python module
import ipywidgets as widgets
from IPython.display import display

# Text box
textbox = widgets.Text(
    placeholder='Your name here'
)

# A label to place next to the text box
label = widgets.Label(
    value="What's your name?"
)

# 'Submit' button
button = widgets.Button(
    description='Submit',
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
)

# Output area for the widgets
output = widgets.Output()

# Display all the widgets we just made
display(label, textbox, button, output)

# Callback function that's called when the 'Submit' button is clicked.
def on_button_clicked(b):
    with output:
        # Remove all previous output
        output.clear_output()
        # Say hello
        print(f'Hello {textbox.value}, you just used a Jupyter widget!')

# Attach the 'button' widget to the callback function.
button.on_click(on_button_clicked)

# %% [markdown]
# *See:* https://ipywidgets.readthedocs.io/en/stable/index.html

# %% [markdown]
# ## 5. Drag your tabs all over

# %% [markdown]
# Another area where JupyterLab and Google Colab differ. To see two separate notebooks side-by-side in Google Colab, you'll have to open the second Colab notebook separately in another browser window (or in a tab, then detach the tab).
#
# Here's what I was going for, as shown in JupyterLab:

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## 6. Is your kernel busy, lazy, or dead?

# %% [markdown]
# In the background, executing all your notebook code, is a Python "kernel." We're going to be running some code that can take a very long time to finish - or that may never finish! When your kernel is busy it's unlikely to be creating any output, which can make it hard to tell what's happening. However, you can see if the Python kernel is busy by looking at the kernel status checkmark in the top left of the notebook. It'll look like this:
# <img src="data:image/png;base64,..." />
#
# If there's a checkmark your kernel is idle, and there's some other reason you're not seeing any output. If there are three horizontal dots, your kernel is busy. You can wait longer, or kill the kernel by going to the "Runtime" menu and clicking "Interrupt execution."

# %% [markdown]
# ## 7. Troubleshooting

# %% [markdown]
# Lots can go wrong, but here are some ideas to get you back on track.

# %% [markdown]
# ### 7.1. Restart your kernel

# %% [markdown]
# Jupyter has what is called a "kernel," which is the background code interpreter that executes code from your notebook cells - we're using "Python 3" as a kernel. It's often the case that we execute some code that made our Python kernel unhappy, or, that put our environment into a state that's interfering with new code we're trying to execute. To start from a clean slate, restart the Python kernel by going to the "Runtime" menu, then clicking "Restart runtime."
#
# *Remember!* You'll probably want to re-execute ealier code cells again if you depend on certain modules being loaded or variables being set.

# %% [markdown]
# ### 7.2. Execute cells in order

# %% [markdown]
# It's possible that code further down in your notebook depends on code being executed in previous cells. If you suspect you might be suffering from executing cells out-of-order you can restart your kernel, then execute code cells top-to-bottom.

# %% [markdown]
# ### 7.3. Start again from a new copy of the notebook

# %% [markdown]
# TODO: The way to do this will depend on how I share my notebooks.

# %% [markdown]
# ## 8. Places to get more help on Jupyter notebooks

# %% [markdown]
# TODO:

# %% [markdown]
# # Functions: Domain, range, co-domains (and more?!)

# %% [markdown]
# Reviewing this will help us all be on the same page when we talk about hash functions.

# %% [markdown]
# * ***Function*** - A rule or process that accepts certain values as input and assigns to each valid input *exactly one* output value.
# * ***Domain*** - A set of all possible values that are considered valid input for a particular function, 'f()'.
# * ***Co-domain*** - Values (output) that "may possibly come out of a function" (*Math is Fun*, below)
# * ***Range*** - The set of all values that can be obtained by applying a function, 'f()', to every value in the domain. A subset of the co-domain.
# * ***Element*** - One item from a domain or co-domain. This term may be used in place of terms like "value," "input," or "output".

# %% [markdown]
# *See:* [Domain, Range and Codomain](https://www.mathsisfun.com/sets/domain-range-codomain.html) at *Math is Fun*

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# *Notice that:*
# * All elements in the domain map to a *single* element in the range
# * Elements in the range may have more than one element from the domain that maps to it
# * $f()$ is a generic, undefined function. It could be any function, it's just standing in as a placeholder.

# %% [markdown]
# ## Function mad libs

# %% [markdown]
# There are a lot of ways someone might say that a function `f()` is operating on a value `A`, which in turn produces the value `B`. This is my attempt to cover all those ways.
#
# `f()`...
# * Is executed, applied, run
# * It "operates on", produces, provides, "results in", "maps to" or simply "maps"
#
# `A`
# * Is an element, input, a value, "data", "the pre-image" (use only if writing textbooks)
#
# `B`
# * Is an element, output, a value, "data", "the image" (again, for textbooks), "the product"
#
#
# *Examples:*
# * "Applying `f()` to `A`, we get `B`" ... "produces `B`" ... "results in `B`"
# * `B` is produced when `A` is provided as input to `f()`
# * "F of `A` is `B`" / "Executing F of `A` results in `B`"
# * "F maps `A` to `B`"
# * *And on and on...*

# %% [markdown]
# ## Example

# %% [markdown]
# ## $f(x) = x^2$

# %% [markdown]
# * This function accepts the set of real numbers as input values.
# * Since $f(x)$ squares the input value, the *range* (or output value) cannot be negative. So we could say "The range of $f(x)$ is the set of all non-negative real numbers."
# * Real numbers, then, could be considered the co-domain.

# %% [markdown]
# # A handy hashing widget for later

# %% [markdown]
# In my Rainbow Table notebook it's often helpful to be able to easily create hash digests. Rather than constantly scrolling around in that notebook, I've added that widget here. So keep this notebook open to refer back to as you go through the Rainbow Tables notebook.

# %%
from Hash_Widgets import hash_display
hash_display()

# %% [markdown]
# # Terminology

# %% [markdown]
# * *Algorithm* - Like a recipe or a script for an actor, an algorithm describes a set of instructions to be performed to reach a desired outcome. (*See:* [Wikipedia](https://en.wikipedia.org/wiki/Algorithm)
# * *Function* - A rule or process that accepts certain values as input and assigns to each valid input exactly one output value. (See above, but also see: [Wikipedia](https://en.wikipedia.org/wiki/Function_(mathematics)))
# * *Hash* - A function that maps data of arbitrary size to fixed-sized value. (*From:* [Wikipedia](https://en.wikipedia.org/wiki/Hash_function))
# * *Hash digest* - What we call the output (or *result*) of a hash function.
# * *Hash space* - A space (or *set*) containing all possible hash digests that a particular hash algorithm can produce.
# * *Integer* - A subset of the natural numbers ranging from negative to positive, and including zero. `..., -1, 0, 1, ...` (*See:* [Wikipedia](https://en.wikipedia.org/wiki/Integer))
# * *Iteration* - Very simliar to a "repetition"; used to describe doing the same thing again. "How long did it take you to reach this prototype?" "It took hundreds of iterations."
# * *Key* - For our purposes here, the term "key" is used interchangably with "password" and possibly even "plain text."
# * *Key:Digest pair* - Communicates that we're talking about a key and its corresponding hash digest - the result after hashing a key. If the key `abc`, when hashed, produced the digest `xyz`, then we'd put them together in the pair `abc:xyz`.
# * *Key space* - Like a hash space, a key space contains all the possible *keys* that can exist, given some known key restrictions. For example, if we said "All keys must be two numbers in length, using the digits 0-9]," then the corresponding key space is all the numbers from `00` to `99`.
#     * Strangely, [Wikipedia](https://en.wikipedia.org/w/index.php?title=Key_space_(cryptography)&redirect=no) doesn't define "key space" the same way I do here. They speak in terms of bits, which, I understand why they're doing it that way, but, makes things more complicated.
# * *Maps* or *Mapping* - When we say 'A' maps to 'B', we mean that some process/function/algorithm is acting on 'A' and as a result, produces (maps to) 'B'. See "Function mad libs", above.
# * *Password* - The prized string of characters that should be unique, difficult to guess, and kept secret. I'll often use the terms "key" or "plain text key" interchangably with "password."
# * *Plain text* - AKA "Key" or "Password." Saying *plain text* emphasizes that the contents of the text haven't been subjected to encryption or hashing. It also implies that this is the part the human deals with.
# * *String* - This might have two, slightly different meanings depending on the context.
#     * *The way I'll probably use the term* - The same way someone might go "He made a series of errors." "I made a *string* of mistakes." "Take a *string of characters* and apply the hash function."
#     * *In a programming context* - A group of characters without much restriction on those characters."
#         * *In Python:*
#             * "This" is definitely a string.
#             * 5 is an integer
#             * "5" is a string, because it's in quotes. This means Python won't treat it like an integer.
#         * The word "String," in the programming context, probably won't come up in these workshops.
